# %%
# EDA- analyze and get useful information from a dataset

# %% [markdown]
# # steps:
#     1.check missing values(df.isnull().sum()) -insights
#     2.check duplicates (df.duplicated().sum()) -insights
#     3.check data types(df.info()) -insights
#     4.check unique values of each column (df.nunique()) -insights
#     5.check decribe dataset (df.describe())-min,max,25%,50%,75%,mean,std,count -insights
#     6.explore more info:
#         6.1 segregate catagorical ,numerical
#     7.Extra features -in student csv we can create total score,avg score.
#     histplot based on other features ,ex.lunch,gender,parental level education,race ethnecity
#     8.co relation -sns.headmap(df)

# %%
# quiz
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("winequality-red.csv")
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
plt.subplot(1,2,1)
sb.histplot(df['alcohol'],kde=True)
plt.subplot(1,2,2)
sb.histplot(df['pH'],kde=True)

# plt.subplot(2,1,1)
# sb.histplot(df['residual sugar'],kde=True)
# Fixed acidity -noook


#  Residual sugar-ook


#  pH


# Alcohol
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
plt.subplot(1,2,1)
sb.histplot(df['residual sugar'],kde=True)
plt.subplot(1,2,2)
sb.histplot(df['fixed acidity'],kde=True)
# Out:
# <Axes: xlabel='fixed acidity', ylabel='Count'>

# %%
df_copy=df.corr()
df_copy[df_copy['quality'] >0]
# Out:
#                 fixed acidity  volatile acidity  citric acid  residual sugar  \
# fixed acidity        1.000000         -0.256131     0.671703        0.114777
# citric acid          0.671703         -0.552496     1.000000        0.143577
# residual sugar       0.114777          0.001918     0.143577        1.000000
# sulphates            0.183006         -0.260987     0.312770        0.005527
# alcohol             -0.061668         -0.202288     0.109903        0.042075
# quality              0.124052         -0.390558     0.226373        0.013732
#
#                 chlorides  free sulfur dioxide  total sulfur dioxide  \
# fixed acidity    0.093705            -0.153794             -0.113181
# citric acid      0.203823            -0.060978              0.035533
# residual sugar   0.055610             0.187049              0.203028
# sulphates        0.371260             0.051658              0.042947
# alcohol         -0.221141            -0.069408             -0.205654
# ...
