# %%
import pandas as pd
csv=pd.read_csv("titanic.csv")
csv
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# # describe the columns which has data types as object

# %%
csv.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
csv.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
csv.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
csv2=csv[csv.dtypes[csv.dtypes =="object"].index]
csv2
# Out:
#                                              Name     Sex              Ticket  \
# 0                                Kelly, Mr. James    male              330911
# 1                Wilkes, Mrs. James (Ellen Needs)  female              363272
# 2                       Myles, Mr. Thomas Francis    male              240276
# 3                                Wirz, Mr. Albert    male              315154
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female             3101298
# ..                                            ...     ...                 ...
# 413                            Spector, Mr. Woolf    male           A.5. 3236
# 414                  Oliva y Ocana, Dona. Fermina  female            PC 17758
# 415                  Saether, Mr. Simon Sivertsen    male  SOTON/O.Q. 3101262
# 416                           Ware, Mr. Frederick    male              359309
# 417                      Peter, Master. Michael J    male                2668
#
#     Cabin Embarked
# ...

# %%
csv[csv.dtypes[csv.dtypes =="object"].index].describe()bb
# Out:
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %%
csv.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # describe column which has data type as float

# %%
csv[csv.dtypes[csv.dtypes=="float"].index].describe()
# Out:
#               Age        Fare
# count  332.000000  417.000000
# mean    30.272590   35.627188
# std     14.181209   55.907576
# min      0.170000    0.000000
# 25%     21.000000    7.895800
# 50%     27.000000   14.454200
# 75%     39.000000   31.500000
# max     76.000000  512.329200

# %%
csv
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# # fillter 10 to 100 values but jump2 in name and passanger id

# %%
csv[["PassengerId","Name"]][10:100:2]
# Out:
#     PassengerId                                               Name
# 10          902                                   Ilieff, Mr. Ylio
# 12          904      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14          906  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 16          908                                  Keane, Mr. Daniel
# 18          910                       Ilmakangas, Miss. Ida Livija
# 20          912                             Rothschild, Mr. Martin
# 22          914               Flegenheim, Mrs. Alfred (Antoinette)
# 24          916    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26          918                       Ostby, Miss. Helene Ragnhild
# 28          920                            Brady, Mr. John Bertram
# 30          922                       Louch, Mr. Charles Alexander
# 32          924           Dean, Mrs. Bertram (Eva Georgetta Light)
# 34          926                           Mock, Mr. Philipp Edmund
# ...

# %%
csv
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# # Add new column is equal to Fare plus tax ,tax=100euro and give new column value as Total fare with tax

# %%
csv["tax"]=100

# %%
csv["Total fare"]=csv['Fare']+csv['tax']

# %%
csv
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %% [markdown]
# # find how many catagories in class column

# %%
pd.Categorical(csv["Pclass"])
# Out:
# [3, 3, 2, 3, 3, ..., 3, 1, 3, 3, 3]
# Length: 418
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(csv["Sex"])
# Out:
# ['male', 'female', 'male', 'male', 'female', ..., 'male', 'female', 'male', 'male', 'male']
# Length: 418
# Categories (2, object): ['female', 'male']

# %%
b

# %% [markdown]
# # find unique values in column

# %%
csv["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# # How many adults in titanic

# %%
csv
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
csv[csv["Age"] >18]
# Out:
#      PassengerId  Pclass                                             Name  \
# 0            892       3                                 Kelly, Mr. James
# 1            893       3                 Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                        Myles, Mr. Thomas Francis
# 3            895       3                                 Wirz, Mr. Albert
# 4            896       3     Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                              ...
# 407         1299       1                       Widener, Mr. George Dunton
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 415         1307       3                     Saether, Mr. Simon Sivertsen
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
len(csv[csv["Age"] >18])
# total 278 persons are adults
# Out:
# 278

# %%
len(csv)-len(csv[csv["Age"] >18])
# total 140 persons are no adults
# Out:
# 140

# %% [markdown]
# # How many male  pay fare less than avg

# %%
mean_fare=csv["Fare"].mean()
pays_less_than_avg=csv[csv["Fare"] < mean_fare]
pays_less_than_avg
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 412         1304       3                Henriksson, Miss. Jenny Lovisa
# 413         1305       3                            Spector, Mr. Woolf
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked  \
# ...

# %%
pays_less_than_avg["Sex"]=="male"
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 412    False
# 413     True
# 415     True
# 416     True
# 417     True
# Name: Sex, Length: 320, dtype: bool

# %%
pays_less_than_avg[pays_less_than_avg["Sex"]=="male"]
# Out:
#      PassengerId  Pclass                          Name   Sex   Age  SibSp  \
# 0            892       3              Kelly, Mr. James  male  34.5      0
# 2            894       2     Myles, Mr. Thomas Francis  male  62.0      0
# 3            895       3              Wirz, Mr. Albert  male  27.0      0
# 5            897       3    Svensson, Mr. Johan Cervin  male  14.0      0
# 7            899       2  Caldwell, Mr. Albert Francis  male  26.0      1
# ..           ...     ...                           ...   ...   ...    ...
# 406         1298       2     Ware, Mr. William Jeffery  male  23.0      1
# 413         1305       3            Spector, Mr. Woolf  male   NaN      0
# 415         1307       3  Saether, Mr. Simon Sivertsen  male  38.5      0
# 416         1308       3           Ware, Mr. Frederick  male   NaN      0
# 417         1309       3      Peter, Master. Michael J  male   NaN      1
#
#      Parch              Ticket     Fare Cabin Embarked  tax  Total fare
# ...

# %%
len(pays_less_than_avg[pays_less_than_avg["Sex"]=="male"])
# Out:
# 221

# %%
# 221 males are paid fare less than avg price

# %% [markdown]
# # who are all paid no fare

# %%
csv
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
csv[csv['Fare'] ==0]['Name']
# Out:
# 266    Chisholm, Mr. Roderick Robert Crispin
# 372                  Ismay, Mr. Joseph Bruce
# Name: Name, dtype: object

# %% [markdown]
# # How many no of male and female in titanic

# %%
csv[csv["Sex"]=="male"]
# Out:
#      PassengerId  Pclass                          Name   Sex   Age  SibSp  \
# 0            892       3              Kelly, Mr. James  male  34.5      0
# 2            894       2     Myles, Mr. Thomas Francis  male  62.0      0
# 3            895       3              Wirz, Mr. Albert  male  27.0      0
# 5            897       3    Svensson, Mr. Johan Cervin  male  14.0      0
# 7            899       2  Caldwell, Mr. Albert Francis  male  26.0      1
# ..           ...     ...                           ...   ...   ...    ...
# 407         1299       1    Widener, Mr. George Dunton  male  50.0      1
# 413         1305       3            Spector, Mr. Woolf  male   NaN      0
# 415         1307       3  Saether, Mr. Simon Sivertsen  male  38.5      0
# 416         1308       3           Ware, Mr. Frederick  male   NaN      0
# 417         1309       3      Peter, Master. Michael J  male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  tax  Total fare
# ...

# %%
len(csv[csv["Sex"]=="male"])
# male =266
# Out:
# 266

# %%
len(csv[csv["Sex"]=="female"])
# female=152
# Out:
# 152

# %% [markdown]
# #  How many persons paid for class 1 ticket

# %%
csv
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
csv[csv["Pclass"]==1]
# Out:
#      PassengerId  Pclass                                               Name  \
# 11           903       1                         Jones, Mr. Charles Cresson
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 20           912       1                             Rothschild, Mr. Martin
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# ..           ...     ...                                                ...
# 403         1295       1                             Carrau, Mr. Jose Pedro
# 404         1296       1                       Frauenthal, Mr. Isaac Gerald
# 407         1299       1                         Widener, Mr. George Dunton
# 411         1303       1    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 414         1306       1                       Oliva y Ocana, Dona. Fermina
#
# ...

# %%
len(csv[csv["Pclass"]==1])
# Out:
# 107

# %%
csv
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %% [markdown]
# # How many female  pay fare more than avg in desc order

# %%
csv
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
avg=csv['Fare'].mean()
print(avg)
female=csv[csv['Sex']=="female"]

female[female["Fare"]>avg]
# Out:
# 35.6271884892086
#      PassengerId  Pclass                                               Name  \
# 12           904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 14           906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 26           918       1                       Ostby, Miss. Helene Ragnhild
# 44           936       1   Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)
# 48           940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 53           945       1                         Fortune, Miss. Ethel Flora
# 59           951       1                        Chaudanson, Miss. Victorine
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 74           966       1                               Geiger, Miss. Amalie
# 92           984       1               Davidson, Mrs. Thornton (Orian Hays)
# ...

# %%
len(female[female["Fare"]>avg])
# Out:
# 53

# %%
df2 = female[female["Fare"]>avg].sort_values('Fare', ascending=False)
df2
# Out:
#      PassengerId  Pclass                                               Name  \
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 53           945       1                         Fortune, Miss. Ethel Flora
# 24           916       1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 375         1267       1                           Bowen, Miss. Grace Scott
# 59           951       1                        Chaudanson, Miss. Victorine
# 184         1076       1  Douglas, Mrs. Frederick Charles (Mary Helene B...
# 114         1006       1             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 156         1048       1                                  Bird, Miss. Ellen
# 218         1110       1       Widener, Mrs. George Dunton (Eleanor Elkins)
# 74           966       1                               Geiger, Miss. Amalie
# ...

# %% [markdown]
# # Who pays max price for ticket

# %%
max_price=csv['Fare'].max()
persons_who_paid_max=csv[csv['Fare']==max_price]

# %%
persons_who_paid_max['Name']
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
# Top 5 persons who pays max price for ticket in each class

# %%
csv
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
# max 5 values

# %%
df=pd.read_csv("titanic.csv")
lis=df["Fare"].unique()
print(type(lis))
# Out:
# <class 'numpy.ndarray'>

# %%
# Out:
#      PassengerId  Pclass                                               Name  \
# 266         1158       1              Chisholm, Mr. Roderick Robert Crispin
# 372         1264       1                            Ismay, Mr. Joseph Bruce
# 21           913       3                          Olsen, Master. Artur Karl
# 133         1025       3                              Thomas, Mr. Charles P
# 116         1008       3                                   Thomas, Mr. John
# ..           ...     ...                                                ...
# 59           951       1                        Chaudanson, Miss. Victorine
# 53           945       1                         Fortune, Miss. Ethel Flora
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 343         1235       1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 152         1044       3                                 Storey, Mr. Thomas
#
# ...

# %%
max_scores = df.groupby('Pclass')['Fare'].nlargest(5)
min_scores= df.groupby('Pclass')['Fare'].nsmallest(5)
# display max_scores
print(max_scores)
print(min_scores)
# Out:
# Pclass
# 1       343    512.3292
#         53     263.0000
#         69     263.0000
#         24     262.3750
#         59     262.3750
# 2       212     73.5000
#         352     73.5000
#         230     65.0000
#         353     65.0000
#         385     65.0000
# 3       188     69.5500
#         342     69.5500
#         360     69.5500
#         365     69.5500
#         39      56.4958
# Name: Fare, dtype: float64
# Pclass
# 1       266     0.0000
#         372     0.0000
#         77     25.7000
#         205    25.7417
#         11     26.0000
# 2       2       9.6875
#         198    10.5000
#         204    10.5000
#         207    10.5000
#         222    10.5000
# 3       21      3.1708
#         116     6.4375
#         133     6.4375
#         232     6.4958
#         291     6.9500
# Name: Fare, dtype: float64
